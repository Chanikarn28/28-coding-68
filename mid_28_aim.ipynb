# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanikarn28/28-coding-68/blob/main/mid_28_aim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#รับข้อมูล (input)
a = int(input("กรุณาระบุคะแนน(p) :"))

#ประมวลผล(PROCESS)
if a >200:
  print("ผ่านเกณฑ์ TCAS")
if a <200:
 print("ต้องพัฒนาเพิ่ม")
# Out:
# กรุณาระบุคะแนน(p) :100
# ต้องพัฒนาเพิ่ม
